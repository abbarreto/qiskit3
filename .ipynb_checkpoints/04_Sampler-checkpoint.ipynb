# %% [markdown]
# # Amostrador primitivo (Sampler primitive)
#
# https://qiskit.org/documentation/partners/qiskit_ibm_runtime/tutorials/how-to-getting-started-with-sampler.html
#
# Cria um circuito aleatório. Depois inicializa a classe Sampler.

# %%
from qiskit.circuit.random import random_circuit

circuit = random_circuit(2, 2, seed=0, measure=True).decompose(reps=1)
display(circuit.draw("mpl"))

# %%
from qiskit.primitives import Sampler

sampler = Sampler()
